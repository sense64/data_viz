# %% [markdown]
# <a href="https://colab.research.google.com/github/sense64/data_viz/blob/main/data_Exploration_prg01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **굵은 텍스트**#Data Exploration
# 데이터 탐색을 위한 모듈 및 패키지를 import 함

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #판다스 사용하기(데이터 프레임)
#
# 판다스 사용법 익히기

# %%
#데이터 파일을 불러오고, 데이터 확인
df = pd.read_csv('/content/drive/MyDrive/kaggle_data/Data Carrard et al. 2022 MedTeach.csv')
df.head()
# Out:
#    id  age  year  sex  glang  part  job  stud_h  health  psyt  jspe  qcae_cog  \
# 0   2   18     1    1    120     1    0      56       3     0    88        62
# 1   4   26     4    1      1     1    0      20       4     0   109        55
# 2   9   21     3    2      1     0    0      36       3     0   106        64
# 3  10   21     2    2      1     0    1      51       5     0   101        52
# 4  13   21     3    1      1     1    0      22       4     0   102        58
#
#    qcae_aff  amsp  erec_mean  cesd  stai_t  mbi_ex  mbi_cy  mbi_ea
# 0        27    17   0.738095    34      61      17      13      20
# 1        37    22   0.690476     7      33      14      11      26
# 2        39    17   0.690476    25      73      24       7      23
# 3        33    18   0.833333    17      48      16      10      21
# 4        28    21   0.690476    14      46      22      14      23

# %% [markdown]
# *이탤릭체 텍스트*# 새 섹션

# %%
df.shape #컬럼과 행을 확인함
df.info() #컬럼별 데이터타입 확인
#print(f"The dataset has {df.shape[0]} rows and {df.shape[1]} columns.")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886 entries, 0 to 885
# Data columns (total 20 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         886 non-null    int64
#  1   age        886 non-null    int64
#  2   year       886 non-null    int64
#  3   sex        886 non-null    int64
#  4   glang      886 non-null    int64
#  5   part       886 non-null    int64
#  6   job        886 non-null    int64
#  7   stud_h     886 non-null    int64
#  8   health     886 non-null    int64
#  9   psyt       886 non-null    int64
#  10  jspe       886 non-null    int64
#  11  qcae_cog   886 non-null    int64
#  12  qcae_aff   886 non-null    int64
#  13  amsp       886 non-null    int64
#  14  erec_mean  886 non-null    float64
#  15  cesd       886 non-null    int64
#  16  stai_t     886 non-null    int64
#  17  mbi_ex     886 non-null    int64
#  18  mbi_cy     886 non-null    int64
#  19  mbi_ea     886 non-null    int64
# ...

# %%
df.columns #컬럼명 확인
# Out:
# Index(['id', 'age', 'year', 'sex', 'glang', 'part', 'job', 'stud_h', 'health',
#        'psyt', 'jspe', 'qcae_cog', 'qcae_aff', 'amsp', 'erec_mean', 'cesd',
#        'stai_t', 'mbi_ex', 'mbi_cy', 'mbi_ea'],
#       dtype='object')

# %%
df.isnull().sum() #결측치가 몇개 있는지 확인
# Out:
# id           0
# age          0
# year         0
# sex          0
# glang        0
# part         0
# job          0
# stud_h       0
# health       0
# psyt         0
# jspe         0
# qcae_cog     0
# qcae_aff     0
# amsp         0
# erec_mean    0
# cesd         0
# stai_t       0
# mbi_ex       0
# mbi_cy       0
# mbi_ea       0
# dtype: int64

# %%
df['mbi_ea'] = df['mbi_ea'].fillna(df.mbi_ea.mean()) # 결측치 부분을 평균으로 대체

# 만약 결측치가 문자열 스페이스(' ')로 되어 있다면, np.nan으로 바꾸어 Pandas 라이브러리가 인식할수 있도록 변환
df.viewCount = df.viewCount.replace('', np.nan)

# 결측치를 제거하는 방법
df.dropna(how='all').head() # 한 행이 모두 missing value이면 제거
df.dropna(how='any').head() # 한 행에서 하나라도 missing value가 있으면 제거

# %%
#범주형 데이터 확인
pd.crosstab(df['year'], df['sex'], margins=True, margins_name='All') #빈도확인
# Out:
# sex     1    2  3  All
# year
# 1      60  184  1  245
# 2      46   89  0  135
# 3      49   94  0  143
# 4      38   84  1  123
# 5      41   85  1  127
# 6      41   70  2  113
# All   275  606  5  886

# %%
pd.crosstab(df['year'], df['sex'], normalize='all')*100 #전체백분율
pd.crosstab(df['year'], df['sex'], normalize='index')*100 #행백분율
# Out:
# sex           1          2         3
# year
# 1     24.489796  75.102041  0.408163
# 2     34.074074  65.925926  0.000000
# 3     34.265734  65.734266  0.000000
# 4     30.894309  68.292683  0.813008
# 5     32.283465  66.929134  0.787402
# 6     36.283186  61.946903  1.769912

# %%
df.isnull().sum()
# Out:
# id           0
# age          0
# year         0
# sex          0
# glang        0
# part         0
# job          0
# stud_h       0
# health       0
# psyt         0
# jspe         0
# qcae_cog     0
# qcae_aff     0
# amsp         0
# erec_mean    0
# cesd         0
# stai_t       0
# mbi_ex       0
# mbi_cy       0
# mbi_ea       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'age', 'year', 'sex', 'glang', 'part', 'job', 'stud_h', 'health',
#        'psyt', 'jspe', 'qcae_cog', 'qcae_aff', 'amsp', 'erec_mean', 'cesd',
#        'stai_t', 'mbi_ex', 'mbi_cy', 'mbi_ea'],
#       dtype='object')

# %%
df_num = df[['age', 'psyt', 'jspe', 'qcae_cog', 'qcae_aff', 'amsp', 'erec_mean', 'cesd',
       'stai_t', 'mbi_ex', 'mbi_cy', 'mbi_ea' ]]
#print(df_num.head())
df.describe()
# Out:
#    age  psyt  jspe  qcae_cog  qcae_aff  amsp  erec_mean  cesd  stai_t  mbi_ex  \
# 0   18     0    88        62        27    17   0.738095    34      61      17
# 1   26     0   109        55        37    22   0.690476     7      33      14
# 2   21     0   106        64        39    17   0.690476    25      73      24
# 3   21     0   101        52        33    18   0.833333    17      48      16
# 4   21     0   102        58        28    21   0.690476    14      46      22
#
#    mbi_cy  mbi_ea
# 0      13      20
# 1      11      26
# 2       7      23
# 3      10      21
# 4      14      23
#                 id         age        year         sex       glang  \
# count   886.000000  886.000000  886.000000  886.000000  886.000000
# mean    889.709932   22.383747    3.102709    1.695260   14.327314
# std     515.555875    3.300664    1.763937    0.472665   32.366389
# min       2.000000   17.000000    1.000000    1.000000    1.000000
# ...

# %%
numerical_columns = ['Age', 'What is your CGPA?']

for column in numerical_columns:
    plt.figure(figsize=(10, 4))
    sns.histplot(data=df, x=column, kde=True)
    plt.title(f"Distribution of {column}")
    plt.show()
