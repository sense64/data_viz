# %% [markdown]
# <a href="https://colab.research.google.com/github/sense64/data_viz/blob/main/dataframe_prg02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
file="/content/drive/MyDrive/ML Lecture/data/vehicle.csv"
df= pd.read_csv(file, encoding='CP949') #한글
df.head()
# Out:
#   Unnamed: 0   2019   2020   2021   2022   2023
# 0         중국   7.71   7.95  11.96  15.84  16.33
# 1       유럽연합  19.02  17.71  15.00  16.70  17.48
# 2         미국  10.47   8.45   5.58   7.60   8.40
# 3         일본  10.87  10.83   7.55   9.09   7.88
# 4         한국   4.04   3.78   3.45   4.20   4.62

# %%
import pandas as pd
file="/content/drive/MyDrive/ML Lecture/data/vehicle.csv"
df= pd.read_csv(file, encoding='CP949', index_col=0) #한글
df.head()
# Out:
#        2019   2020   2021   2022   2023
# 중국     7.71   7.95  11.96  15.84  16.33
# 유럽연합  19.02  17.71  15.00  16.70  17.48
# 미국    10.47   8.45   5.58   7.60   8.40
# 일본    10.87  10.83   7.55   9.09   7.88
# 한국     4.04   3.78   3.45   4.20   4.62

# %%
#total 열을  생성
df['total'] = df['2019']+df['2020'] + df['2021']
df.head()
# Out:
#        2019   2020   2021   2022   2023  total
# 중국     7.71   7.95  11.96  15.84  16.33  27.62
# 유럽연합  19.02  17.71  15.00  16.70  17.48  51.73
# 미국    10.47   8.45   5.58   7.60   8.40  24.50
# 일본    10.87  10.83   7.55   9.09   7.88  29.25
# 한국     4.04   3.78   3.45   4.20   4.62  11.27

# %%
#total 열을 삭제 drop() 사용
df.drop('total', inplace=True, axis=1)
df.head()
# Out:
#        2019   2020   2021   2022   2023
# 중국     7.71   7.95  11.96  15.84  16.33
# 유럽연합  19.02  17.71  15.00  16.70  17.48
# 미국    10.47   8.45   5.58   7.60   8.40
# 일본    10.87  10.83   7.55   9.09   7.88
# 한국     4.04   3.78   3.45   4.20   4.62

# %%
#total과 mean 열 삽입
df['total'] = df[['2019', '2020', '2021', '2022', '2023']].sum(axis=1)
df['mean']=df.mean(axis=1) #열전체를 평균을 구함
df.head()
# Out:
#        2019   2020   2021   2022   2023  total       mean
# 중국     7.71   7.95  11.96  15.84  16.33  59.79  19.930000
# 유럽연합  19.02  17.71  15.00  16.70  17.48  85.91  28.636667
# 미국    10.47   8.45   5.58   7.60   8.40  40.50  13.500000
# 일본    10.87  10.83   7.55   9.09   7.88  46.22  15.406667
# 한국     4.04   3.78   3.45   4.20   4.62  20.09   6.696667
