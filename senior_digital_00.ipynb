# %% [markdown]
# <a href="https://colab.research.google.com/github/sense64/data_viz/blob/main/senior_digital_00.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 주요 패키지 4개 임포트

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel("/content/drive/MyDrive/old_wellbing/sinor_data.xlsx")
df.head()
# Out:
#    no  Q5A1  Q5A2  Q5A3  Q5A4  Q5A5  Q5A6  Q5A7        Q5  Q8B1  ...   Q13  \
# 0   1     2     2     2     3     3     3     3  2.571429     4  ...  1.00
# 1   2     2     3     1     3     1     1     1  1.714286     4  ...  1.00
# 2   3     3     3     1     4     3     1     1  2.285714     4  ...  3.00
# 3   4     2     2     1     2     1     2     1  1.571429     4  ...  2.25
# 4   5     3     3     2     3     2     2     2  2.428571     3  ...  1.50
#
#    Q14B1  Q14B2  Q14B3  Q14B4   Q14  age  gender  wage    wt_가중치
# 0      2      1      1      1  1.25    2       1     6  0.276925
# 1      1      1      1      3  1.50    1       2     3  2.019244
# 2      3      3      3      3  3.00    1       2     4  0.671010
# 3      2      2      3      2  2.25    2       2     4  1.910782
# 4      1      1      1      1  1.00    2       1     3  0.775390
#
# [5 rows x 45 columns]
#    no  Q5A1  Q5A2  Q5A3  Q5A4  Q5A5  Q5A6  Q5A7        Q5  Q8B1  ...   Q13  \
# 0   1     2     2     2     3     3     3     3  2.571429     4  ...  1.00
# 1   2     2     3     1     3     1     1     1  1.714286     4  ...  1.00
# 2   3     3     3     1     4     3     1     1  2.285714     4  ...  3.00
# 3   4     2     2     1     2     1     2     1  1.571429     4  ...  2.25
# 4   5     3     3     2     3     2     2     2  2.428571     3  ...  1.50
#
#    Q14B1  Q14B2  Q14B3  Q14B4   Q14  age  gender  wage    wt_가중치
# 0      2      1      1      1  1.25    2       1     6  0.276925
# 1      1      1      1      3  1.50    1       2     3  2.019244
# 2      3      3      3      3  3.00    1       2     4  0.671010
# 3      2      2      3      2  2.25    2       2     4  1.910782
# 4      1      1      1      1  1.00    2       1     3  0.775390
#
# [5 rows x 45 columns]

# %%
# 데이터 정보를 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1808 entries, 0 to 1807
# Data columns (total 45 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   no      1808 non-null   int64
#  1   Q5A1    1808 non-null   int64
#  2   Q5A2    1808 non-null   int64
#  3   Q5A3    1808 non-null   int64
#  4   Q5A4    1808 non-null   int64
#  5   Q5A5    1808 non-null   int64
#  6   Q5A6    1808 non-null   int64
#  7   Q5A7    1808 non-null   int64
#  8   Q5      1808 non-null   float64
#  9   Q8B1    1808 non-null   int64
#  10  Q8B2    1808 non-null   int64
#  11  Q8B3    1808 non-null   int64
#  12  Q8B4    1808 non-null   int64
#  13  Q8      1808 non-null   float64
#  14  Q9B1    1808 non-null   int64
#  15  Q9B2    1808 non-null   int64
#  16  Q9B3    1808 non-null   int64
#  17  Q9B4    1808 non-null   int64
#  18  Q9B5    1808 non-null   int64
#  19  Q9      1808 non-null   float64
#  20  Q10B1   1808 non-null   int64
#  21  Q10B2   1808 non-null   int64
#  22  Q10B3   1808 non-null   int64
#  23  Q10B4   1808 non-null   int64
#  24  Q10     1808 non-null   float64
#  25  Q11B1   1808 non-null   int64
#  26  Q11B2   1808 non-null   int64
#  27  Q11     1808 non-null   float64
#  28  Q12B1   1808 non-null   int64
#  29  Q12B2   1808 non-null   int64
#  30  Q12     1808 non-null   float64
#  31  Q13B1   1808 non-null   int64
#  32  Q13B2   1808 non-null   int64
#  33  Q13B3   1808 non-null   int64
#  34  Q13B4   1808 non-null   int64
#  35  Q13     1808 non-null   float64
#  36  Q14B1   1808 non-null   int64
#  37  Q14B2   1808 non-null   int64
#  38  Q14B3   1808 non-null   int64
#  39  Q14B4   1808 non-null   int64
#  40  Q14     1808 non-null   float64
#  41  age     1808 non-null   int64
#  42  gender  1808 non-null   int64
#  43  wage    1808 non-null   int64
#  44  wt_가중치  1808 non-null   float64
# dtypes: float64(9), int64(36)
# memory usage: 635.8 KB

# %%
#데이터 전처리 과정(결측치 여부)
df.isnull().sum()
# Out:
# no        0
# Q5A1      0
# Q5A2      0
# Q5A3      0
# Q5A4      0
# Q5A5      0
# Q5A6      0
# Q5A7      0
# Q5        0
# Q8B1      0
# Q8B2      0
# Q8B3      0
# Q8B4      0
# Q8        0
# Q9B1      0
# Q9B2      0
# Q9B3      0
# Q9B4      0
# Q9B5      0
# Q9        0
# Q10B1     0
# Q10B2     0
# Q10B3     0
# Q10B4     0
# Q10       0
# Q11B1     0
# Q11B2     0
# Q11       0
# Q12B1     0
# Q12B2     0
# Q12       0
# Q13B1     0
# Q13B2     0
# Q13B3     0
# Q13B4     0
# Q13       0
# Q14B1     0
# Q14B2     0
# Q14B3     0
# Q14B4     0
# Q14       0
# age       0
# gender    0
# wage      0
# wt_가중치    0
# dtype: int64

# %%
#데이터를 범주형과 계량형으로 나누어 데이터 셑을 지정
df_num=df[['Q5','Q8', 'Q10', 'Q11', 'Q12', 'Q13', 'Q14']]
df_cat=df[['age', 'gender', 'wage']]
print(df_num.head(), df_cat.head())
# Out:
#          Q5    Q8   Q10  Q11  Q12   Q13   Q14
# 0  2.571429  2.25  1.75  2.0  2.5  1.00  1.25
# 1  1.714286  2.25  2.50  1.0  2.0  1.00  1.50
# 2  2.285714  2.25  2.50  2.5  3.0  3.00  3.00
# 3  1.571429  2.75  3.00  3.5  3.5  2.25  2.25
# 4  2.428571  1.75  2.50  1.0  2.5  1.50  1.00    age  gender  wage
# 0    2       1     6
# 1    1       2     3
# 2    1       2     4
# 3    2       2     4
# 4    2       1     3

# %%
#1차원 범주형데이터 표로 정리요약
print(df['age'].value_counts()) #빈도를 확인
print(df['age'].value_counts(normalize=True)*100) #비율을 확인
# Out:
# 2    849
# 1    496
# 3    463
# Name: age, dtype: int64
# 2    46.957965
# 1    27.433628
# 3    25.608407
# Name: age, dtype: float64

# %%
#반복문을 이용하여 모든 범주형 데이터의 빈도분석을 한꺼번에 처리
for col in df_cat.columns :
  print(col)
  print(df[col].value_counts())
  print(df[col].value_counts(normalize=True)*100)
  print("=================================")
# Out:
# age
# 2    849
# 1    496
# 3    463
# Name: age, dtype: int64
# 2    46.957965
# 1    27.433628
# 3    25.608407
# Name: age, dtype: float64
# =================================
# gender
# 1    908
# 2    900
# Name: gender, dtype: int64
# 1    50.221239
# 2    49.778761
# Name: gender, dtype: float64
# =================================
# wage
# 3     383
# 4     359
# 2     346
# 5     196
# 6     195
# 7     129
# 1     104
# 8      52
# 9      33
# 11     10
# 10      1
# Name: wage, dtype: int64
# 3     21.183628
# 4     19.856195
# 2     19.137168
# 5     10.840708
# 6     10.785398
# 7      7.134956
# 1      5.752212
# 8      2.876106
# 9      1.825221
# 11     0.553097
# 10     0.055310
# Name: wage, dtype: float64
# =================================
# w
# 5    391
# 3    383
# 4    359
# 2    346
# 6    225
# 1    104
# Name: w, dtype: int64
# 5    21.626106
# 3    21.183628
# 4    19.856195
# 2    19.137168
# 6    12.444690
# 1     5.752212
# Name: w, dtype: float64
# =================================

# %%
w=[]
for data in df['wage']:
  if data==1 or data==2 or data==3 or data==4 :
    w.append(data)
  elif data==5 or data==6 :
    w.append(5)
  else :
    w.append(6)

df['w'] =pd.DataFrame(w)
df_cat['w'] =pd.DataFrame(w)
# Out:
# <ipython-input-34-3fb02679ae00>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat['w'] =pd.DataFrame(w)

# %%
df_num.describe()
# Out:
#                 Q5          Q8          Q10          Q11          Q12  \
# count  1808.000000  1808.00000  1808.000000  1808.000000  1808.000000
# mean      2.509798     2.14021     2.198977     1.887168     2.217091
# std       0.759785     0.64728     0.756947     0.850789     0.820848
# min       1.000000     1.00000     1.000000     1.000000     1.000000
# 25%       2.000000     1.75000     1.500000     1.000000     1.500000
# 50%       2.571429     2.00000     2.250000     2.000000     2.000000
# 75%       3.000000     2.50000     2.750000     2.500000     3.000000
# max       4.000000     4.00000     4.000000     4.000000     4.000000
#
#                Q13          Q14
# count  1808.000000  1808.000000
# mean      1.591814     1.666897
# std       0.765906     0.766743
# min       1.000000     1.000000
# 25%       1.000000     1.000000
# 50%       1.000000     1.500000
# 75%       2.000000     2.250000
# max       4.000000     4.000000

# %% [markdown]
# # 2차원 데이터 탐색

# %%
print(pd.crosstab(df['age'], df['gender'], margins=True))
print(pd.crosstab(df['age'], df['gender'], normalize='all')*100)
print(pd.crosstab(df['age'], df['gender'], normalize='index')*100)
# Out:
# gender    1    2   All
# age
# 1       257  239   496
# 2       429  420   849
# 3       222  241   463
# All     908  900  1808
# gender          1          2
# age
# 1       14.214602  13.219027
# 2       23.727876  23.230088
# 3       12.278761  13.329646
# gender          1          2
# age
# 1       51.814516  48.185484
# 2       50.530035  49.469965
# 3       47.948164  52.051836

# %%
# Out:
# gender          1          2
# age
# 1       14.214602  13.219027
# 2       23.727876  23.230088
# 3       12.278761  13.329646

# %% [markdown]
# # 계량형 2차원 데이터

# %%
df_num.corr()
# Out:
#            Q5        Q8       Q10       Q11       Q12       Q13       Q14
# Q5   1.000000  0.554779  0.586997  0.438572  0.366195  0.381057  0.432286
# Q8   0.554779  1.000000  0.743698  0.588102  0.527910  0.594881  0.641096
# Q10  0.586997  0.743698  1.000000  0.608691  0.538763  0.588334  0.644416
# Q11  0.438572  0.588102  0.608691  1.000000  0.643873  0.675257  0.676167
# Q12  0.366195  0.527910  0.538763  0.643873  1.000000  0.542858  0.564164
# Q13  0.381057  0.594881  0.588334  0.675257  0.542858  1.000000  0.814712
# Q14  0.432286  0.641096  0.644416  0.676167  0.564164  0.814712  1.000000

# %%
# 복합 데이터 분석

print("연령별 경제활동", df['Q14'].groupby(df['age']).mean(), "사회참여", df['Q13'].groupby(df['age']).mean())
# Out:
# 연령별 경제활동 age
# 1    2.010081
# 2    1.652238
# 3    1.326134
# Name: Q14, dtype: float64 사회참여 age
# 1    1.888609
# 2    1.578327
# 3    1.298596
# Name: Q13, dtype: float64

# %%
print("소득별 경제활동", df['Q14'].groupby(df['w']).mean(), "사회참여", df['Q13'].groupby(df['w']).mean())
# Out:
# 소득별 경제활동 w
# 1    1.182692
# 2    1.360549
# 3    1.554178
# 4    1.702646
# 5    1.927110
# 6    2.044444
# Name: Q14, dtype: float64 사회참여 w
# 1    1.192308
# 2    1.334538
# 3    1.494778
# 4    1.633705
# 5    1.802430
# 6    1.904444
# Name: Q13, dtype: float64

# %%
print("소득별 경제활동", df['Q14'].groupby(df['gender']).mean(), "사회참여", df['Q13'].groupby(df['gender']).mean())
# Out:
# 소득별 경제활동 gender
# 1    1.760738
# 2    1.572222
# Name: Q14, dtype: float64 사회참여 gender
# 1    1.677588
# 2    1.505278
# Name: Q13, dtype: float64
